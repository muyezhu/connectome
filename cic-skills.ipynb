# %% [markdown]
# <a href="https://colab.research.google.com/github/muyezhu/connectome/blob/master/cic-skills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
life_expectancy_url = 'https://drive.google.com/file/d/1XZPUcTb2XC9cy67iXI6ogU47ygOiaO9e/view?usp=sharing'
df = pd.read_csv(life_expectancy_url, header=1, usecols=[0,1])
df
# Out:
#                                                                                                                                                                                                                                                                                                                 Unnamed: 0 null
# NaN                                                NaN                               5                                     1                               NaN        NaN   1                       https://drive.google.com NaN NaN                                                1   NaN 1   NaN NaN NaN NaN        NaN  NaN
#                                                    6                                 1                                     1                               ND]        NaN   NaN                     NaN                      NaN NaN                                                NaN NaN NaN NaN NaN NaN NaN        NaN  NaN
# ...
